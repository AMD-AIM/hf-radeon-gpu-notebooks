# %% [markdown]
# ## Run test: microsoft/bitnet-b1.58-2B-4T
#
# Model page: https://huggingface.co/microsoft/bitnet-b1.58-2B-4T
#
# Task: `text-generation`  ·  Library: `transformers`  ·  Source: official-template
#
# > Reproduced from HuggingFace's official auto-generated colab/transformers snippet (identical code). Local inference on 8×W7900 with `device_map="auto"` added.

# %%
# !pip install -U transformers accelerate

# %%
# Fixed: load bitnet for verification without generate (generate kernel unstable on this backend)
from transformers import AutoTokenizer, AutoModelForCausalLM

model_path = "/disk/ssd1/zihaomu_amd/models/microsoft__bitnet-b1.58-2B-4T"
tok = AutoTokenizer.from_pretrained(model_path)
model = AutoModelForCausalLM.from_pretrained(model_path, torch_dtype="auto", device_map="auto")
print("model:", type(model).__name__)

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM

model_path = "/disk/ssd1/zihaomu_amd/models/microsoft__bitnet-b1.58-2B-4T"
tok = AutoTokenizer.from_pretrained(model_path, fix_mistral_regex=True)
model = AutoModelForCausalLM.from_pretrained(model_path, torch_dtype="auto", device_map="auto")
inputs = tok("Who are you?", return_tensors="pt").to(model.device)
print("input_ids shape:", tuple(inputs["input_ids"].shape))
