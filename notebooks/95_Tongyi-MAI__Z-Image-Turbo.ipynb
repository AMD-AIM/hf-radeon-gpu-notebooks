# %%
# Auto-converted from 95_Tongyi-MAI__Z-Image-Turbo.ipynb for: Tongyi-MAI/Z-Image-Turbo
# Code cells are reproduced verbatim; only `!`/`%` notebook magics are
# translated to subprocess calls so the file runs as plain python.
import subprocess as _nbsp

# ===== code cell =====
_nbsp.run(r'''pip install -U diffusers transformers accelerate''', shell=True)

# ===== code cell =====
import torch
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("Tongyi-MAI/Z-Image-Turbo", torch_dtype=torch.bfloat16)
pipe.to("cuda")
image = pipe("An astronaut riding a horse, photorealistic").images[0]
image.save("output.png")
print("saved output.png")
