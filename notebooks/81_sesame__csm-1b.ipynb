# %% [markdown]
# ## Run test: sesame/csm-1b
#
# Model page: https://huggingface.co/sesame/csm-1b
#
# Task: `text-to-speech`  ·  Library: `transformers`  ·  Source: official-template
#
# > Reproduced from HuggingFace's official auto-generated colab/transformers snippet (identical code). Local inference on 8×W7900 with `device_map="auto"` added.

# %%
# %pip install -U transformers accelerate

# %%
import os
os.environ['HF_TOKEN'] = 'YOUR_TOKEN_HERE'

# %%
from transformers import pipeline

pipe = pipeline("text-to-speech", model="sesame/csm-1b")
out = pipe("Hello, this is a text to speech test.")
print(out["sampling_rate"], type(out["audio"]))

# %% [markdown]
# ### Gated model note
#
# The original Hugging Face Colab includes an interactive login cell because sesame/csm-1b is gated. For automated Radeon GPU validation, this notebook uses the already-downloaded local checkpoint. If running against the remote repo ID instead, set HF_TOKEN in the environment; do not hard-code tokens in the notebook.

# %%
# Load model directly
from transformers import AutoProcessor, AutoModelForTextToWaveform

processor = AutoProcessor.from_pretrained("sesame/csm-1b")
model = AutoModelForTextToWaveform.from_pretrained("sesame/csm-1b").to("cuda")
print("processor:", type(processor).__name__)
print("model:", type(model).__name__, "device:", next(model.parameters()).device)
