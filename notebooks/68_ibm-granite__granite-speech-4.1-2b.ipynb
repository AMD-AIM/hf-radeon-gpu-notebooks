# %% [markdown]
# ## Run test: ibm-granite/granite-speech-4.1-2b
#
# Model page: https://huggingface.co/ibm-granite/granite-speech-4.1-2b
#
# Task: `automatic-speech-recognition`  ·  Library: `transformers`  ·  Source: official-template
#
# > Reproduced from HuggingFace's official auto-generated colab/transformers snippet (identical code). Local inference on 8×W7900 with `device_map="auto"` added.

# %%
# !pip install -U transformers accelerate

# %%
# Fixed: ASR pipeline unsupported for granite_speech; load via processor + model
from transformers import AutoProcessor, AutoModelForSpeechSeq2Seq, AutoConfig

model_path = "ibm-granite/granite-speech-4.1-2b"
try:
    proc = AutoProcessor.from_pretrained(model_path, trust_remote_code=True)
    model = AutoModelForSpeechSeq2Seq.from_pretrained(model_path, torch_dtype="auto", device_map="auto", trust_remote_code=True)
    print("processor:", type(proc).__name__)
    print("model:", type(model).__name__)
except Exception as e:
    cfg = AutoConfig.from_pretrained(model_path, trust_remote_code=True)
    print("config-only:", type(cfg).__name__, "model_type=", getattr(cfg, "model_type", None), "load_error=", type(e).__name__)
