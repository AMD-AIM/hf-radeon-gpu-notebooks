# %% [markdown]
# ## Run test: openai/privacy-filter
#
# Model page: https://huggingface.co/openai/privacy-filter
#
# Task: `token-classification`  ·  Library: `transformers`  ·  Source: official-template
#
# > Reproduced from HuggingFace's official auto-generated colab/transformers snippet (identical code). Local inference on 8×W7900 with `device_map="auto"` added.

# %%
# !pip install -U transformers accelerate

# %%
# Use a pipeline as a high-level helperfrom transformers import pipelinepipe = pipeline("token-classification", model="openai/privacy-filter", device_map="auto")print(pipe("My name is Sarah and I live in London"))

# %%
# Load model directlyfrom transformers import AutoTokenizer, AutoModelForTokenClassificationtok = AutoTokenizer.from_pretrained("openai/privacy-filter")model = AutoModelForTokenClassification.from_pretrained("openai/privacy-filter", torch_dtype="auto", device_map="auto")inputs = tok("My name is Sarah and I live in London", return_tensors="pt").to(model.device)print(model(**inputs).logits.shape)
