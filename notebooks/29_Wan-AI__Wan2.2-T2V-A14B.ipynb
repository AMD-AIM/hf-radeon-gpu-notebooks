# %% [markdown]
# ## Run test: Wan-AI/Wan2.2-T2V-A14B
#
# Aligned with the Hugging Face generated Colab local-inference section. Inference Providers snippets are ignored because they do not validate local AMD GPU loading.

# %%
# No local GPU code snippets are available yet for this library in the Hugging Face generated Colab.
# The Colab points users to the repository files and the library documentation instead.
raise RuntimeError("HF Colab has no local GPU inference snippet for Wan-AI/Wan2.2-T2V-A14B; Inference Providers are ignored for this validation.")
