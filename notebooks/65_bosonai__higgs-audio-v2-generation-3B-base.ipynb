# %%
# Auto-converted from 65_bosonai__higgs-audio-v2-generation-3B-base.ipynb for: bosonai/higgs-audio-v2-generation-3B-base
# Local-inference cells only; remote-inference section is dropped.
# Code cells reproduced verbatim; only shell/magic install lines are
# translated to subprocess calls so the file runs as plain python.
import subprocess as _nbsp

# ===== code cell =====
_nbsp.run(r'''pip install -U transformers''', shell=True)

# ===== code cell =====
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-to-speech", model="bosonai/higgs-audio-v2-generation-3B-base")

# ===== code cell =====
# Load model directly
from transformers import AutoProcessor, AutoModelForTextToWaveform

processor = AutoProcessor.from_pretrained("bosonai/higgs-audio-v2-generation-3B-base")
model = AutoModelForTextToWaveform.from_pretrained("bosonai/higgs-audio-v2-generation-3B-base")
