# %%
# Auto-converted from 33_google__gemma-4-12B-it-qat-q4_0-unquantized.ipynb for: google/gemma-4-12B-it-qat-q4_0-unquantized
# Local-inference cells only; remote-inference section is dropped.
# Code cells reproduced verbatim; only shell/magic install lines are
# translated to subprocess calls so the file runs as plain python.
import subprocess as _nbsp

# ===== code cell =====
_nbsp.run(r'''pip install -U transformers''', shell=True)

# ===== code cell =====
# Load model directly
from transformers import AutoProcessor, AutoModelForMultimodalLM

processor = AutoProcessor.from_pretrained("google/gemma-4-12B-it-qat-q4_0-unquantized")
model = AutoModelForMultimodalLM.from_pretrained("google/gemma-4-12B-it-qat-q4_0-unquantized")
