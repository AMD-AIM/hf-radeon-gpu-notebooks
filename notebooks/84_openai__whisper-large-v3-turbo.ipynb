# %% [markdown]
# ## Run test: openai/whisper-large-v3-turbo
#
# Model page: https://huggingface.co/openai/whisper-large-v3-turbo
#
# Task: `automatic-speech-recognition`  ·  Library: `transformers`  ·  Source: official-template
#
# > Reproduced from HuggingFace's official auto-generated colab/transformers snippet (identical code). Local inference on 8×W7900 with `device_map="auto"` added.

# %%
# !pip install -U transformers accelerate

# %%
from pathlib import Path
from transformers import pipeline

pipe = pipeline(
    "automatic-speech-recognition",
    model="/disk/ssd1/zihaomu_amd/models/openai__whisper-large-v3-turbo",
    device_map="auto",
)
audio_path = "sample.flac"
if Path(audio_path).exists():
    print(pipe(audio_path))
else:
    print(f"skip inference: {audio_path} not found")
