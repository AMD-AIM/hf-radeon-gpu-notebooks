# %% [markdown]
# ## Run test: google/siglip2-base-patch16-naflex
#
# Model page: https://huggingface.co/google/siglip2-base-patch16-naflex
#
# Task: `zero-shot-image-classification`  ·  Library: `transformers`  ·  Source: official-template
#
# > Reproduced from HuggingFace's official auto-generated colab/transformers snippet (identical code). Local inference on 8×W7900 with `device_map="auto"` added.

# %%
# !pip install -U transformers accelerate

# %%
# Use a pipeline as a high-level helperfrom transformers import pipelinepipe = pipeline("zero-shot-image-classification", model="/disk/ssd1/zihaomu_amd/models/google__siglip2-base-patch16-naflex", device_map="auto")# replace with your image pathprint(pipe("image.jpg", candidate_labels=["a photo of a cat", "a photo of a dog", "a photo of a car"]))

# %%
# Load model directlyfrom transformers import AutoModel, AutoProcessorproc = AutoProcessor.from_pretrained("/disk/ssd1/zihaomu_amd/models/google__siglip2-base-patch16-naflex")model = AutoModel.from_pretrained("/disk/ssd1/zihaomu_amd/models/google__siglip2-base-patch16-naflex", torch_dtype="auto", device_map="auto")# from PIL import Image# img = Image.open("your.jpg")# inputs = proc(text=["a cat", "a dog"], images=img, padding="max_length", return_tensors="pt").to(model.device)# print(model(**inputs).logits_per_image.softmax(dim=1))
