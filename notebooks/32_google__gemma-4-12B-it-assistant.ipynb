# %%
# Modified from old notebooks_py/32_google__gemma-4-12B-it-assistant.py: chat_template
# usage removed per user request (use plain-text prompt instead). Rest as-is.
import subprocess as _nbsp

# ===== code cell =====
_nbsp.run(r'''pip install -U transformers accelerate''', shell=True)

# ===== code cell =====
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("any-to-any", model="/disk/ssd1/zihaomu_amd/models/google__gemma-4-12B", device_map="auto")
print(pipe("Who are you?", max_new_tokens=64))

# ===== code cell =====
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tok = AutoTokenizer.from_pretrained("/disk/ssd1/zihaomu_amd/models/google__gemma-4-12B")
model = AutoModelForCausalLM.from_pretrained("/disk/ssd1/zihaomu_amd/models/google__gemma-4-12B", torch_dtype="auto", device_map="auto")
inputs = tok("Who are you?", return_tensors="pt").to(model.device)
out = model.generate(**inputs, max_new_tokens=64)
print(tok.decode(out[0][inputs["input_ids"].shape[-1]:]))
