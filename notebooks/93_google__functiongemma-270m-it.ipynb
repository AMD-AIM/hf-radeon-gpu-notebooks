# %%
# Auto-converted from 93_google__functiongemma-270m-it.ipynb for: google/functiongemma-270m-it
# Local-inference cells only; remote-inference section is dropped.
# Code cells reproduced verbatim; only shell/magic install lines are
# translated to subprocess calls so the file runs as plain python.
import subprocess as _nbsp

_nbsp.run(r'''pip install -U transformers''', shell=True)

# %%
import os
os.environ['HF_TOKEN'] = 'YOUR_TOKEN_HERE'

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("text-generation", model="/disk/ssd1/zihaomu_amd/models/google__functiongemma-270m-it")

# %%
# Load model directly
from transformers import AutoModel
model = AutoModel.from_pretrained("/disk/ssd1/zihaomu_amd/models/google__functiongemma-270m-it", dtype="auto")
