# %%
# Auto-converted from 108_google__gemma-3n-E4B-it.ipynb for: google/gemma-3n-E4B-it
# Code cells are reproduced verbatim; only `!`/`%` notebook magics are
# translated to subprocess calls so the file runs as plain python.
import subprocess as _nbsp

_nbsp.run(r'''pip install -U transformers accelerate''', shell=True)

# %%
import os
os.environ['HF_TOKEN'] = 'YOUR_TOKEN_HERE'

# %%
import os
from huggingface_hub import login

_hf_token = os.environ.get("HF_TOKEN")
if _hf_token and _hf_token != "YOUR_TOKEN_HERE":
    login(token=_hf_token)
else:
    print("HF_TOKEN not set or still placeholder; skipping interactive login and using local model files.")

# %%
# Use a pipeline as a high-level helperfrom transformers import pipelinepipe = pipeline("image-text-to-text", model="/disk/ssd1/zihaomu_amd/models/google__gemma-3n-E4B-it", device_map="auto")messages = [    {"role": "user", "content": "Who are you?"},]print(pipe(messages, max_new_tokens=64))

# %%
# Load model directly
from transformers import AutoTokenizer, AutoModelForCausalLM

tok = AutoTokenizer.from_pretrained("/disk/ssd1/zihaomu_amd/models/google__gemma-3n-E4B-it")
model = AutoModelForCausalLM.from_pretrained("/disk/ssd1/zihaomu_amd/models/google__gemma-3n-E4B-it", torch_dtype="auto", device_map="auto")
messages = [{"role": "user", "content": "Who are you?"}]
inputs = tok.apply_chat_template(messages, add_generation_prompt=True, tokenize=True, return_dict=True, return_tensors="pt").to(model.device)
out = model.generate(**inputs, max_new_tokens=64)
print(tok.decode(out[0][inputs["input_ids"].shape[-1]:]))
