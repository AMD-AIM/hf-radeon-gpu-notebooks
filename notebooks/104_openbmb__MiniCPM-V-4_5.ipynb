# %% [markdown]
# ## Run test: openbmb/MiniCPM-V-4_5
#
# Model page: https://huggingface.co/openbmb/MiniCPM-V-4_5
#
# Task: `image-text-to-text`  ·  Library: `transformers`  ·  Source: official-template
#
# > Reproduced from HuggingFace's official auto-generated colab/transformers snippet (identical code). Local inference on 8×W7900 with `device_map="auto"` added.

# %%
# !pip install -U transformers accelerate

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("image-text-to-text", model="openbmb/MiniCPM-V-4_5", device_map="auto", trust_remote_code=True)
messages = [{'role': 'user',
  'content': [{'type': 'image',
               'url': 'https://huggingface.co/datasets/huggingface/documentation-images/resolve/main/p-blog/candy.JPG'},
              {'type': 'text', 'text': 'What animal is on the candy?'}]}]
print(pipe(text=messages, max_new_tokens=64))

# %%
# Load model directly
from transformers import AutoModel

model = AutoModel.from_pretrained("openbmb/MiniCPM-V-4_5", trust_remote_code=True, dtype="auto")
print("model:", type(model).__name__)
