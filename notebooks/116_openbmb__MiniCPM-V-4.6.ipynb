# %% [markdown]
# ## Run test: openbmb/MiniCPM-V-4.6
#
# Model page: https://huggingface.co/openbmb/MiniCPM-V-4.6
#
# Task: `image-text-to-text`  ·  Library: `transformers`  ·  Source: official-template
#
# > Reproduced from HuggingFace's official auto-generated colab/transformers snippet (identical code). Local inference on 8×W7900 with `device_map="auto"` added.

# %%
# !pip install -U transformers accelerate

# %%
# Use a pipeline as a high-level helperfrom transformers import pipelinepipe = pipeline("image-text-to-text", model="/disk/ssd1/zihaomu_amd/models/openbmb__MiniCPM-V-4.6", device_map="auto")messages = [    {"role": "user", "content": "Who are you?"},]print(pipe(messages, max_new_tokens=64))

# %%
# Load model directlyfrom transformers import AutoTokenizer, AutoModelForCausalLMtok = AutoTokenizer.from_pretrained("/disk/ssd1/zihaomu_amd/models/openbmb__MiniCPM-V-4.6")model = AutoModelForCausalLM.from_pretrained("/disk/ssd1/zihaomu_amd/models/openbmb__MiniCPM-V-4.6", torch_dtype="auto", device_map="auto")messages = [{"role": "user", "content": "Who are you?"}]inputs = tok.apply_chat_template(messages, add_generation_prompt=True, tokenize=True, return_dict=True, return_tensors="pt").to(model.device)out = model.generate(**inputs, max_new_tokens=64)print(tok.decode(out[0][inputs["input_ids"].shape[-1]:]))
