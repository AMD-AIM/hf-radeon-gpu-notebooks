# %% [markdown]
# ## Run test: google/translategemma-4b-it
#
# Model page: https://huggingface.co/google/translategemma-4b-it
#
# Task: `image-text-to-text`  ·  Library: `transformers`  ·  Source: official-template
#
# > Reproduced from HuggingFace's official auto-generated colab/transformers snippet (identical code). Local inference on 8×W7900 with `device_map="auto"` added.

# %%
# !pip install -U transformers accelerate

# %%
import os
os.environ['HF_TOKEN'] = 'YOUR_TOKEN_HERE'

# %% [markdown]
# ⚠️ This model is **gated**: accept the license on the model page first, then set `HF_TOKEN` or log in.

# %%
import os
from huggingface_hub import login

_hf_token = os.environ.get("HF_TOKEN")
if _hf_token and _hf_token != "YOUR_TOKEN_HERE":
    login(token=_hf_token)
else:
    print("HF_TOKEN not set or still placeholder; skipping interactive login and using local model files.")

# %%
# Use a pipeline as a high-level helper
from transformers import pipeline

pipe = pipeline("image-text-to-text", model="/disk/ssd1/zihaomu_amd/models/google__translategemma-4b-it", device_map="auto")
messages = [
    {
        "role": "user",
        "content": [
            {
                "type": "text",
                "source_lang_code": "en",
                "target_lang_code": "zh",
                "text": "Who are you?",
                "image": None,
            }
        ],
    }
]
print(pipe(messages, max_new_tokens=64))

# %%
# Load model directly (fixed: VLM uses image-text-to-text head)
from transformers import AutoProcessor, AutoModelForImageTextToText

model_path = "/disk/ssd1/zihaomu_amd/models/google__translategemma-4b-it"
proc = AutoProcessor.from_pretrained(model_path, trust_remote_code=True)
model = AutoModelForImageTextToText.from_pretrained(model_path, torch_dtype="auto", device_map="auto", trust_remote_code=True)
print("processor:", type(proc).__name__)
print("model:", type(model).__name__)
